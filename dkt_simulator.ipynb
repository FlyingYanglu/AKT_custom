# %%
import numpy as np
import json

# Step 1: Initialize Parameters
num_students = 2000
num_exercises = 50
num_concepts = 5
guess_probability = 0.25
learning_rate = 0.1  # Example learning rate for skill update

# Step 2: Generate Latent Knowledge States
student_skills = np.random.randn(num_students, num_concepts)  # Normally distributed skills

# Step 3: Generate Exercise Parameters
exercise_concepts = np.random.randint(0, num_concepts, num_exercises) # Randomly assign concepts to exercises
exercise_difficulties = np.random.randn(num_exercises)  # Normally distributed difficulties

# Step 4: Simulate Student Responses and Update Skills in Real-Time
def probability_correct(alpha, beta, c=guess_probability):
    return c + (1 - c) / (1 + np.exp(-alpha + beta))

responses = np.zeros((num_students, num_exercises))

data_list = []

for student in range(num_students):
    for exercise in range(num_exercises):
        concept = exercise_concepts[exercise]
        difficulty = exercise_difficulties[exercise]
        skill = student_skills[student, concept]
        prob_correct = probability_correct(skill, difficulty)
        correct = np.random.binomial(1, prob_correct)
        responses[student, exercise] = correct

        # Create a dictionary entry for each response
        entry = {
            'student_id': int(student),
            'concept': int(concept),
            'exercise_id': int(exercise),
            'difficulty': float(difficulty),
            'skill': float(skill),
            'response': int(correct)  # Ensure it's an int for JSON serialization
        }
        data_list.append(entry)

        # Update skill based on the response
        if correct:
            student_skills[student, concept] += learning_rate
        else:
            student_skills[student, concept] -= learning_rate

# Save the data list as a JSON file
with open('custom_dataset/data_list.json', 'w') as json_file:
    json.dump(data_list, json_file)

print("Data saved successfully as JSON.")
# Out:
# Data saved successfully as JSON.

# %%
data_list
# Out:
# [{'student_id': 0,
#   'concept': 3.0,
#   'exercise_id': 0,
#   'difficulty': 0.8196367556597587,
#   'skill': -1.0942014362698367,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 0.0,
#   'exercise_id': 1,
#   'difficulty': 0.8913040281589579,
#   'skill': -0.17282499745742386,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 0.0,
#   'exercise_id': 2,
#   'difficulty': -0.5531372419066192,
#   'skill': -0.27282499745742383,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 1.0,
#   'exercise_id': 3,
#   'difficulty': 0.26159009433817343,
#   'skill': -0.02301228244654323,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 1.0,
#   'exercise_id': 4,
#   'difficulty': 1.3116985069874925,
#   'skill': 0.07698771755345678,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 1.0,
#   'exercise_id': 5,
#   'difficulty': -1.3698887412990906,
#   'skill': 0.17698771755345677,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 0.0,
#   'exercise_id': 6,
#   'difficulty': -0.679139310129589,
#   'skill': -0.17282499745742383,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 1.0,
#   'exercise_id': 7,
#   'difficulty': -0.8018765891256632,
#   'skill': 0.07698771755345676,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 0.0,
#   'exercise_id': 8,
#   'difficulty': 2.4063205269141164,
#   'skill': -0.07282499745742382,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 4.0,
#   'exercise_id': 9,
#   'difficulty': -1.5078561945166784,
#   'skill': 0.8312122005003812,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 3.0,
#   'exercise_id': 10,
#   'difficulty': -0.022425673102465113,
#   'skill': -1.1942014362698368,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 3.0,
#   'exercise_id': 11,
#   'difficulty': -1.0936176901944472,
#   'skill': -1.0942014362698367,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 1.0,
#   'exercise_id': 12,
#   'difficulty': 1.6304738660787466,
#   'skill': -0.023012282446543242,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 4.0,
#   'exercise_id': 13,
#   'difficulty': 0.013057203517021837,
#   'skill': 0.9312122005003812,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 2.0,
#   'exercise_id': 14,
#   'difficulty': 0.6043042468961399,
#   'skill': 0.25138566224278974,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 1.0,
#   'exercise_id': 15,
#   'difficulty': 0.5918590749516477,
#   'skill': -0.12301228244654325,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 4.0,
#   'exercise_id': 16,
#   'difficulty': -0.10768281406872234,
#   'skill': 1.0312122005003812,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 2.0,
#   'exercise_id': 17,
#   'difficulty': -1.6279829749561132,
#   'skill': 0.3513856622427898,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 0.0,
#   'exercise_id': 18,
#   'difficulty': 0.9484587395186511,
#   'skill': -0.17282499745742383,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 0.0,
#   'exercise_id': 19,
#   'difficulty': -0.6037662024584216,
#   'skill': -0.27282499745742383,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 1.0,
#   'exercise_id': 20,
#   'difficulty': -1.0715204934528981,
#   'skill': -0.023012282446543242,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 4.0,
#   'exercise_id': 21,
#   'difficulty': 1.427237599596769,
#   'skill': 1.1312122005003813,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 2.0,
#   'exercise_id': 22,
#   'difficulty': 0.4802272568058525,
#   'skill': 0.45138566224278975,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 2.0,
#   'exercise_id': 23,
#   'difficulty': -2.2122614060271517,
#   'skill': 0.3513856622427898,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 3.0,
#   'exercise_id': 24,
#   'difficulty': -1.0648103301748373,
#   'skill': -0.9942014362698367,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 2.0,
#   'exercise_id': 25,
#   'difficulty': 1.4798167460616558,
#   'skill': 0.45138566224278975,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 1.0,
#   'exercise_id': 26,
#   'difficulty': 1.025125490347724,
#   'skill': 0.07698771755345676,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 0.0,
#   'exercise_id': 27,
#   'difficulty': -0.4466836523187057,
#   'skill': -0.17282499745742383,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 1.0,
#   'exercise_id': 28,
#   'difficulty': -0.30856417843088296,
#   'skill': 0.17698771755345677,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 2.0,
#   'exercise_id': 29,
#   'difficulty': -0.053601797087209455,
#   'skill': 0.5513856622427897,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 4.0,
#   'exercise_id': 30,
#   'difficulty': 0.22509968717234413,
#   'skill': 1.0312122005003812,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 2.0,
#   'exercise_id': 31,
#   'difficulty': -0.21490662841544653,
#   'skill': 0.45138566224278975,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 4.0,
#   'exercise_id': 32,
#   'difficulty': 0.6709310009375185,
#   'skill': 1.1312122005003813,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 2.0,
#   'exercise_id': 33,
#   'difficulty': 0.4928586532738607,
#   'skill': 0.3513856622427898,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 0.0,
#   'exercise_id': 34,
#   'difficulty': -0.5170969983699942,
#   'skill': -0.27282499745742383,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 3.0,
#   'exercise_id': 35,
#   'difficulty': -0.6966971402416068,
#   'skill': -1.0942014362698367,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 0.0,
#   'exercise_id': 36,
#   'difficulty': -0.5193471703510235,
#   'skill': -0.17282499745742383,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 3.0,
#   'exercise_id': 37,
#   'difficulty': -0.026160198615202756,
#   'skill': -0.9942014362698367,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 1.0,
#   'exercise_id': 38,
#   'difficulty': -0.28465499701484015,
#   'skill': 0.07698771755345676,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 0.0,
#   'exercise_id': 39,
#   'difficulty': -0.9896105378462159,
#   'skill': -0.27282499745742383,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 0.0,
#   'exercise_id': 40,
#   'difficulty': -0.0019626349165605974,
#   'skill': -0.17282499745742383,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 2.0,
#   'exercise_id': 41,
#   'difficulty': -0.29610299245474186,
#   'skill': 0.2513856622427898,
#   'response': 0},
#  {'student_id': 0,
#   'concept': 2.0,
#   'exercise_id': 42,
#   'difficulty': 0.39625990944493245,
#   'skill': 0.1513856622427898,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 4.0,
#   'exercise_id': 43,
#   'difficulty': -2.1641233284389427,
#   'skill': 1.0312122005003812,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 3.0,
#   'exercise_id': 44,
#   'difficulty': 0.8092447404136248,
#   'skill': -0.8942014362698367,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 4.0,
#   'exercise_id': 45,
#   'difficulty': 0.8853520320789972,
#   'skill': 1.1312122005003813,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 2.0,
#   'exercise_id': 46,
#   'difficulty': -0.9531938619909409,
#   'skill': 0.2513856622427898,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 4.0,
#   'exercise_id': 47,
#   'difficulty': 0.07467215243986028,
#   'skill': 1.2312122005003814,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 0.0,
#   'exercise_id': 48,
#   'difficulty': -0.467589388362164,
#   'skill': -0.27282499745742383,
#   'response': 1},
#  {'student_id': 0,
#   'concept': 3.0,
#   'exercise_id': 49,
#   'difficulty': -0.035869957346887436,
#   'skill': -0.7942014362698367,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 3.0,
#   'exercise_id': 0,
#   'difficulty': 0.8196367556597587,
#   'skill': 0.45181166016197005,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 0.0,
#   'exercise_id': 1,
#   'difficulty': 0.8913040281589579,
#   'skill': 0.03980168382036266,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 0.0,
#   'exercise_id': 2,
#   'difficulty': -0.5531372419066192,
#   'skill': -0.06019831617963735,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 1.0,
#   'exercise_id': 3,
#   'difficulty': 0.26159009433817343,
#   'skill': 0.10375317411558879,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 1.0,
#   'exercise_id': 4,
#   'difficulty': 1.3116985069874925,
#   'skill': 0.0037531741155887866,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 1.0,
#   'exercise_id': 5,
#   'difficulty': -1.3698887412990906,
#   'skill': 0.10375317411558879,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 0.0,
#   'exercise_id': 6,
#   'difficulty': -0.679139310129589,
#   'skill': 0.03980168382036266,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 1.0,
#   'exercise_id': 7,
#   'difficulty': -0.8018765891256632,
#   'skill': 0.2037531741155888,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 0.0,
#   'exercise_id': 8,
#   'difficulty': 2.4063205269141164,
#   'skill': -0.06019831617963735,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 4.0,
#   'exercise_id': 9,
#   'difficulty': -1.5078561945166784,
#   'skill': -0.08111692764140864,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 3.0,
#   'exercise_id': 10,
#   'difficulty': -0.022425673102465113,
#   'skill': 0.55181166016197,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 3.0,
#   'exercise_id': 11,
#   'difficulty': -1.0936176901944472,
#   'skill': 0.65181166016197,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 1.0,
#   'exercise_id': 12,
#   'difficulty': 1.6304738660787466,
#   'skill': 0.3037531741155888,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 4.0,
#   'exercise_id': 13,
#   'difficulty': 0.013057203517021837,
#   'skill': 0.018883072358591366,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 2.0,
#   'exercise_id': 14,
#   'difficulty': 0.6043042468961399,
#   'skill': 0.922663966646572,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 1.0,
#   'exercise_id': 15,
#   'difficulty': 0.5918590749516477,
#   'skill': 0.40375317411558875,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 4.0,
#   'exercise_id': 16,
#   'difficulty': -0.10768281406872234,
#   'skill': 0.11888307235859137,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 2.0,
#   'exercise_id': 17,
#   'difficulty': -1.6279829749561132,
#   'skill': 0.822663966646572,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 0.0,
#   'exercise_id': 18,
#   'difficulty': 0.9484587395186511,
#   'skill': -0.16019831617963737,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 0.0,
#   'exercise_id': 19,
#   'difficulty': -0.6037662024584216,
#   'skill': -0.06019831617963736,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 1.0,
#   'exercise_id': 20,
#   'difficulty': -1.0715204934528981,
#   'skill': 0.5037531741155887,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 4.0,
#   'exercise_id': 21,
#   'difficulty': 1.427237599596769,
#   'skill': 0.018883072358591366,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 2.0,
#   'exercise_id': 22,
#   'difficulty': 0.4802272568058525,
#   'skill': 0.922663966646572,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 2.0,
#   'exercise_id': 23,
#   'difficulty': -2.2122614060271517,
#   'skill': 1.022663966646572,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 3.0,
#   'exercise_id': 24,
#   'difficulty': -1.0648103301748373,
#   'skill': 0.75181166016197,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 2.0,
#   'exercise_id': 25,
#   'difficulty': 1.4798167460616558,
#   'skill': 1.122663966646572,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 1.0,
#   'exercise_id': 26,
#   'difficulty': 1.025125490347724,
#   'skill': 0.6037531741155887,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 0.0,
#   'exercise_id': 27,
#   'difficulty': -0.4466836523187057,
#   'skill': -0.16019831617963737,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 1.0,
#   'exercise_id': 28,
#   'difficulty': -0.30856417843088296,
#   'skill': 0.5037531741155887,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 2.0,
#   'exercise_id': 29,
#   'difficulty': -0.053601797087209455,
#   'skill': 1.022663966646572,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 4.0,
#   'exercise_id': 30,
#   'difficulty': 0.22509968717234413,
#   'skill': -0.08111692764140864,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 2.0,
#   'exercise_id': 31,
#   'difficulty': -0.21490662841544653,
#   'skill': 1.122663966646572,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 4.0,
#   'exercise_id': 32,
#   'difficulty': 0.6709310009375185,
#   'skill': 0.018883072358591366,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 2.0,
#   'exercise_id': 33,
#   'difficulty': 0.4928586532738607,
#   'skill': 1.2226639666465722,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 0.0,
#   'exercise_id': 34,
#   'difficulty': -0.5170969983699942,
#   'skill': -0.06019831617963736,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 3.0,
#   'exercise_id': 35,
#   'difficulty': -0.6966971402416068,
#   'skill': 0.65181166016197,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 0.0,
#   'exercise_id': 36,
#   'difficulty': -0.5193471703510235,
#   'skill': 0.03980168382036264,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 3.0,
#   'exercise_id': 37,
#   'difficulty': -0.026160198615202756,
#   'skill': 0.75181166016197,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 1.0,
#   'exercise_id': 38,
#   'difficulty': -0.28465499701484015,
#   'skill': 0.6037531741155887,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 0.0,
#   'exercise_id': 39,
#   'difficulty': -0.9896105378462159,
#   'skill': 0.13980168382036265,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 0.0,
#   'exercise_id': 40,
#   'difficulty': -0.0019626349165605974,
#   'skill': 0.23980168382036265,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 2.0,
#   'exercise_id': 41,
#   'difficulty': -0.29610299245474186,
#   'skill': 1.122663966646572,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 2.0,
#   'exercise_id': 42,
#   'difficulty': 0.39625990944493245,
#   'skill': 1.022663966646572,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 4.0,
#   'exercise_id': 43,
#   'difficulty': -2.1641233284389427,
#   'skill': 0.11888307235859137,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 3.0,
#   'exercise_id': 44,
#   'difficulty': 0.8092447404136248,
#   'skill': 0.65181166016197,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 4.0,
#   'exercise_id': 45,
#   'difficulty': 0.8853520320789972,
#   'skill': 0.2188830723585914,
#   'response': 0},
#  {'student_id': 1,
#   'concept': 2.0,
#   'exercise_id': 46,
#   'difficulty': -0.9531938619909409,
#   'skill': 1.122663966646572,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 4.0,
#   'exercise_id': 47,
#   'difficulty': 0.07467215243986028,
#   'skill': 0.11888307235859139,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 0.0,
#   'exercise_id': 48,
#   'difficulty': -0.467589388362164,
#   'skill': 0.3398016838203627,
#   'response': 1},
#  {'student_id': 1,
#   'concept': 3.0,
#   'exercise_id': 49,
#   'difficulty': -0.035869957346887436,
#   'skill': 0.75181166016197,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 3.0,
#   'exercise_id': 0,
#   'difficulty': 0.8196367556597587,
#   'skill': 0.15914884217623507,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 0.0,
#   'exercise_id': 1,
#   'difficulty': 0.8913040281589579,
#   'skill': -2.2689631407181228,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 0.0,
#   'exercise_id': 2,
#   'difficulty': -0.5531372419066192,
#   'skill': -2.368963140718123,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 1.0,
#   'exercise_id': 3,
#   'difficulty': 0.26159009433817343,
#   'skill': 2.110099795217977,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 1.0,
#   'exercise_id': 4,
#   'difficulty': 1.3116985069874925,
#   'skill': 2.2100997952179773,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 1.0,
#   'exercise_id': 5,
#   'difficulty': -1.3698887412990906,
#   'skill': 2.110099795217977,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 0.0,
#   'exercise_id': 6,
#   'difficulty': -0.679139310129589,
#   'skill': -2.468963140718123,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 1.0,
#   'exercise_id': 7,
#   'difficulty': -0.8018765891256632,
#   'skill': 2.2100997952179773,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 0.0,
#   'exercise_id': 8,
#   'difficulty': 2.4063205269141164,
#   'skill': -2.568963140718123,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 4.0,
#   'exercise_id': 9,
#   'difficulty': -1.5078561945166784,
#   'skill': -1.5134134642449208,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 3.0,
#   'exercise_id': 10,
#   'difficulty': -0.022425673102465113,
#   'skill': 0.2591488421762351,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 3.0,
#   'exercise_id': 11,
#   'difficulty': -1.0936176901944472,
#   'skill': 0.3591488421762351,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 1.0,
#   'exercise_id': 12,
#   'difficulty': 1.6304738660787466,
#   'skill': 2.3100997952179774,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 4.0,
#   'exercise_id': 13,
#   'difficulty': 0.013057203517021837,
#   'skill': -1.4134134642449208,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 2.0,
#   'exercise_id': 14,
#   'difficulty': 0.6043042468961399,
#   'skill': -1.287574258489254,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 1.0,
#   'exercise_id': 15,
#   'difficulty': 0.5918590749516477,
#   'skill': 2.4100997952179775,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 4.0,
#   'exercise_id': 16,
#   'difficulty': -0.10768281406872234,
#   'skill': -1.5134134642449208,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 2.0,
#   'exercise_id': 17,
#   'difficulty': -1.6279829749561132,
#   'skill': -1.387574258489254,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 0.0,
#   'exercise_id': 18,
#   'difficulty': 0.9484587395186511,
#   'skill': -2.468963140718123,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 0.0,
#   'exercise_id': 19,
#   'difficulty': -0.6037662024584216,
#   'skill': -2.568963140718123,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 1.0,
#   'exercise_id': 20,
#   'difficulty': -1.0715204934528981,
#   'skill': 2.5100997952179775,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 4.0,
#   'exercise_id': 21,
#   'difficulty': 1.427237599596769,
#   'skill': -1.4134134642449208,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 2.0,
#   'exercise_id': 22,
#   'difficulty': 0.4802272568058525,
#   'skill': -1.287574258489254,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 2.0,
#   'exercise_id': 23,
#   'difficulty': -2.2122614060271517,
#   'skill': -1.387574258489254,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 3.0,
#   'exercise_id': 24,
#   'difficulty': -1.0648103301748373,
#   'skill': 0.4591488421762351,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 2.0,
#   'exercise_id': 25,
#   'difficulty': 1.4798167460616558,
#   'skill': -1.4875742584892542,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 1.0,
#   'exercise_id': 26,
#   'difficulty': 1.025125490347724,
#   'skill': 2.6100997952179776,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 0.0,
#   'exercise_id': 27,
#   'difficulty': -0.4466836523187057,
#   'skill': -2.668963140718123,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 1.0,
#   'exercise_id': 28,
#   'difficulty': -0.30856417843088296,
#   'skill': 2.7100997952179777,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 2.0,
#   'exercise_id': 29,
#   'difficulty': -0.053601797087209455,
#   'skill': -1.387574258489254,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 4.0,
#   'exercise_id': 30,
#   'difficulty': 0.22509968717234413,
#   'skill': -1.3134134642449207,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 2.0,
#   'exercise_id': 31,
#   'difficulty': -0.21490662841544653,
#   'skill': -1.4875742584892542,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 4.0,
#   'exercise_id': 32,
#   'difficulty': 0.6709310009375185,
#   'skill': -1.2134134642449206,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 2.0,
#   'exercise_id': 33,
#   'difficulty': 0.4928586532738607,
#   'skill': -1.387574258489254,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 0.0,
#   'exercise_id': 34,
#   'difficulty': -0.5170969983699942,
#   'skill': -2.768963140718123,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 3.0,
#   'exercise_id': 35,
#   'difficulty': -0.6966971402416068,
#   'skill': 0.3591488421762351,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 0.0,
#   'exercise_id': 36,
#   'difficulty': -0.5193471703510235,
#   'skill': -2.668963140718123,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 3.0,
#   'exercise_id': 37,
#   'difficulty': -0.026160198615202756,
#   'skill': 0.4591488421762351,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 1.0,
#   'exercise_id': 38,
#   'difficulty': -0.28465499701484015,
#   'skill': 2.810099795217978,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 0.0,
#   'exercise_id': 39,
#   'difficulty': -0.9896105378462159,
#   'skill': -2.768963140718123,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 0.0,
#   'exercise_id': 40,
#   'difficulty': -0.0019626349165605974,
#   'skill': -2.8689631407181233,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 2.0,
#   'exercise_id': 41,
#   'difficulty': -0.29610299245474186,
#   'skill': -1.4875742584892542,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 2.0,
#   'exercise_id': 42,
#   'difficulty': 0.39625990944493245,
#   'skill': -1.5875742584892543,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 4.0,
#   'exercise_id': 43,
#   'difficulty': -2.1641233284389427,
#   'skill': -1.3134134642449207,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 3.0,
#   'exercise_id': 44,
#   'difficulty': 0.8092447404136248,
#   'skill': 0.5591488421762351,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 4.0,
#   'exercise_id': 45,
#   'difficulty': 0.8853520320789972,
#   'skill': -1.4134134642449208,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 2.0,
#   'exercise_id': 46,
#   'difficulty': -0.9531938619909409,
#   'skill': -1.6875742584892544,
#   'response': 0},
#  {'student_id': 2,
#   'concept': 4.0,
#   'exercise_id': 47,
#   'difficulty': 0.07467215243986028,
#   'skill': -1.3134134642449207,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 0.0,
#   'exercise_id': 48,
#   'difficulty': -0.467589388362164,
#   'skill': -2.9689631407181234,
#   'response': 1},
#  {'student_id': 2,
#   'concept': 3.0,
#   'exercise_id': 49,
#   'difficulty': -0.035869957346887436,
#   'skill': 0.4591488421762351,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 3.0,
#   'exercise_id': 0,
#   'difficulty': 0.8196367556597587,
#   'skill': -0.6003345652386667,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 0.0,
#   'exercise_id': 1,
#   'difficulty': 0.8913040281589579,
#   'skill': -0.4421753509599448,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 0.0,
#   'exercise_id': 2,
#   'difficulty': -0.5531372419066192,
#   'skill': -0.3421753509599448,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 1.0,
#   'exercise_id': 3,
#   'difficulty': 0.26159009433817343,
#   'skill': 0.38539108945150186,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 1.0,
#   'exercise_id': 4,
#   'difficulty': 1.3116985069874925,
#   'skill': 0.2853910894515018,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 1.0,
#   'exercise_id': 5,
#   'difficulty': -1.3698887412990906,
#   'skill': 0.3853910894515018,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 0.0,
#   'exercise_id': 6,
#   'difficulty': -0.679139310129589,
#   'skill': -0.24217535095994477,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 1.0,
#   'exercise_id': 7,
#   'difficulty': -0.8018765891256632,
#   'skill': 0.4853910894515018,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 0.0,
#   'exercise_id': 8,
#   'difficulty': 2.4063205269141164,
#   'skill': -0.14217535095994477,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 4.0,
#   'exercise_id': 9,
#   'difficulty': -1.5078561945166784,
#   'skill': 0.22675588960482834,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 3.0,
#   'exercise_id': 10,
#   'difficulty': -0.022425673102465113,
#   'skill': -0.5003345652386667,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 3.0,
#   'exercise_id': 11,
#   'difficulty': -1.0936176901944472,
#   'skill': -0.6003345652386667,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 1.0,
#   'exercise_id': 12,
#   'difficulty': 1.6304738660787466,
#   'skill': 0.5853910894515018,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 4.0,
#   'exercise_id': 13,
#   'difficulty': 0.013057203517021837,
#   'skill': 0.3267558896048284,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 2.0,
#   'exercise_id': 14,
#   'difficulty': 0.6043042468961399,
#   'skill': 0.22168526990157036,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 1.0,
#   'exercise_id': 15,
#   'difficulty': 0.5918590749516477,
#   'skill': 0.4853910894515018,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 4.0,
#   'exercise_id': 16,
#   'difficulty': -0.10768281406872234,
#   'skill': 0.42675588960482835,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 2.0,
#   'exercise_id': 17,
#   'difficulty': -1.6279829749561132,
#   'skill': 0.32168526990157037,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 0.0,
#   'exercise_id': 18,
#   'difficulty': 0.9484587395186511,
#   'skill': -0.24217535095994477,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 0.0,
#   'exercise_id': 19,
#   'difficulty': -0.6037662024584216,
#   'skill': -0.14217535095994477,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 1.0,
#   'exercise_id': 20,
#   'difficulty': -1.0715204934528981,
#   'skill': 0.5853910894515018,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 4.0,
#   'exercise_id': 21,
#   'difficulty': 1.427237599596769,
#   'skill': 0.5267558896048283,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 2.0,
#   'exercise_id': 22,
#   'difficulty': 0.4802272568058525,
#   'skill': 0.4216852699015704,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 2.0,
#   'exercise_id': 23,
#   'difficulty': -2.2122614060271517,
#   'skill': 0.3216852699015704,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 3.0,
#   'exercise_id': 24,
#   'difficulty': -1.0648103301748373,
#   'skill': -0.7003345652386667,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 2.0,
#   'exercise_id': 25,
#   'difficulty': 1.4798167460616558,
#   'skill': 0.4216852699015704,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 1.0,
#   'exercise_id': 26,
#   'difficulty': 1.025125490347724,
#   'skill': 0.6853910894515017,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 0.0,
#   'exercise_id': 27,
#   'difficulty': -0.4466836523187057,
#   'skill': -0.24217535095994477,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 1.0,
#   'exercise_id': 28,
#   'difficulty': -0.30856417843088296,
#   'skill': 0.5853910894515018,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 2.0,
#   'exercise_id': 29,
#   'difficulty': -0.053601797087209455,
#   'skill': 0.5216852699015704,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 4.0,
#   'exercise_id': 30,
#   'difficulty': 0.22509968717234413,
#   'skill': 0.42675588960482835,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 2.0,
#   'exercise_id': 31,
#   'difficulty': -0.21490662841544653,
#   'skill': 0.6216852699015704,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 4.0,
#   'exercise_id': 32,
#   'difficulty': 0.6709310009375185,
#   'skill': 0.5267558896048283,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 2.0,
#   'exercise_id': 33,
#   'difficulty': 0.4928586532738607,
#   'skill': 0.7216852699015703,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 0.0,
#   'exercise_id': 34,
#   'difficulty': -0.5170969983699942,
#   'skill': -0.3421753509599448,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 3.0,
#   'exercise_id': 35,
#   'difficulty': -0.6966971402416068,
#   'skill': -0.6003345652386667,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 0.0,
#   'exercise_id': 36,
#   'difficulty': -0.5193471703510235,
#   'skill': -0.44217535095994476,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 3.0,
#   'exercise_id': 37,
#   'difficulty': -0.026160198615202756,
#   'skill': -0.7003345652386667,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 1.0,
#   'exercise_id': 38,
#   'difficulty': -0.28465499701484015,
#   'skill': 0.6853910894515017,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 0.0,
#   'exercise_id': 39,
#   'difficulty': -0.9896105378462159,
#   'skill': -0.3421753509599448,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 0.0,
#   'exercise_id': 40,
#   'difficulty': -0.0019626349165605974,
#   'skill': -0.24217535095994477,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 2.0,
#   'exercise_id': 41,
#   'difficulty': -0.29610299245474186,
#   'skill': 0.6216852699015704,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 2.0,
#   'exercise_id': 42,
#   'difficulty': 0.39625990944493245,
#   'skill': 0.7216852699015703,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 4.0,
#   'exercise_id': 43,
#   'difficulty': -2.1641233284389427,
#   'skill': 0.42675588960482835,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 3.0,
#   'exercise_id': 44,
#   'difficulty': 0.8092447404136248,
#   'skill': -0.6003345652386667,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 4.0,
#   'exercise_id': 45,
#   'difficulty': 0.8853520320789972,
#   'skill': 0.5267558896048283,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 2.0,
#   'exercise_id': 46,
#   'difficulty': -0.9531938619909409,
#   'skill': 0.6216852699015704,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 4.0,
#   'exercise_id': 47,
#   'difficulty': 0.07467215243986028,
#   'skill': 0.42675588960482835,
#   'response': 0},
#  {'student_id': 3,
#   'concept': 0.0,
#   'exercise_id': 48,
#   'difficulty': -0.467589388362164,
#   'skill': -0.14217535095994477,
#   'response': 1},
#  {'student_id': 3,
#   'concept': 3.0,
#   'exercise_id': 49,
#   'difficulty': -0.035869957346887436,
#   'skill': -0.5003345652386667,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 3.0,
#   'exercise_id': 0,
#   'difficulty': 0.8196367556597587,
#   'skill': 0.9374685458401472,
#   'response': 0},
#  {'student_id': 4,
#   'concept': 0.0,
#   'exercise_id': 1,
#   'difficulty': 0.8913040281589579,
#   'skill': -0.6483564968566016,
#   'response': 0},
#  {'student_id': 4,
#   'concept': 0.0,
#   'exercise_id': 2,
#   'difficulty': -0.5531372419066192,
#   'skill': -0.7483564968566015,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 1.0,
#   'exercise_id': 3,
#   'difficulty': 0.26159009433817343,
#   'skill': 0.3303427260207648,
#   'response': 0},
#  {'student_id': 4,
#   'concept': 1.0,
#   'exercise_id': 4,
#   'difficulty': 1.3116985069874925,
#   'skill': 0.2303427260207648,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 1.0,
#   'exercise_id': 5,
#   'difficulty': -1.3698887412990906,
#   'skill': 0.3303427260207648,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 0.0,
#   'exercise_id': 6,
#   'difficulty': -0.679139310129589,
#   'skill': -0.6483564968566016,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 1.0,
#   'exercise_id': 7,
#   'difficulty': -0.8018765891256632,
#   'skill': 0.43034272602076484,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 0.0,
#   'exercise_id': 8,
#   'difficulty': 2.4063205269141164,
#   'skill': -0.5483564968566016,
#   'response': 0},
#  {'student_id': 4,
#   'concept': 4.0,
#   'exercise_id': 9,
#   'difficulty': -1.5078561945166784,
#   'skill': 0.16538053442662443,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 3.0,
#   'exercise_id': 10,
#   'difficulty': -0.022425673102465113,
#   'skill': 0.8374685458401472,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 3.0,
#   'exercise_id': 11,
#   'difficulty': -1.0936176901944472,
#   'skill': 0.9374685458401472,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 1.0,
#   'exercise_id': 12,
#   'difficulty': 1.6304738660787466,
#   'skill': 0.5303427260207648,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 4.0,
#   'exercise_id': 13,
#   'difficulty': 0.013057203517021837,
#   'skill': 0.26538053442662446,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 2.0,
#   'exercise_id': 14,
#   'difficulty': 0.6043042468961399,
#   'skill': -0.8684946487129823,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 1.0,
#   'exercise_id': 15,
#   'difficulty': 0.5918590749516477,
#   'skill': 0.6303427260207648,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 4.0,
#   'exercise_id': 16,
#   'difficulty': -0.10768281406872234,
#   'skill': 0.36538053442662444,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 2.0,
#   'exercise_id': 17,
#   'difficulty': -1.6279829749561132,
#   'skill': -0.7684946487129823,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 0.0,
#   'exercise_id': 18,
#   'difficulty': 0.9484587395186511,
#   'skill': -0.6483564968566016,
#   'response': 0},
#  {'student_id': 4,
#   'concept': 0.0,
#   'exercise_id': 19,
#   'difficulty': -0.6037662024584216,
#   'skill': -0.7483564968566015,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 1.0,
#   'exercise_id': 20,
#   'difficulty': -1.0715204934528981,
#   'skill': 0.7303427260207648,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 4.0,
#   'exercise_id': 21,
#   'difficulty': 1.427237599596769,
#   'skill': 0.4653805344266244,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 2.0,
#   'exercise_id': 22,
#   'difficulty': 0.4802272568058525,
#   'skill': -0.6684946487129824,
#   'response': 0},
#  {'student_id': 4,
#   'concept': 2.0,
#   'exercise_id': 23,
#   'difficulty': -2.2122614060271517,
#   'skill': -0.7684946487129823,
#   'response': 0},
#  {'student_id': 4,
#   'concept': 3.0,
#   'exercise_id': 24,
#   'difficulty': -1.0648103301748373,
#   'skill': 1.0374685458401471,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 2.0,
#   'exercise_id': 25,
#   'difficulty': 1.4798167460616558,
#   'skill': -0.8684946487129823,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 1.0,
#   'exercise_id': 26,
#   'difficulty': 1.025125490347724,
#   'skill': 0.8303427260207648,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 0.0,
#   'exercise_id': 27,
#   'difficulty': -0.4466836523187057,
#   'skill': -0.6483564968566016,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 1.0,
#   'exercise_id': 28,
#   'difficulty': -0.30856417843088296,
#   'skill': 0.9303427260207647,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 2.0,
#   'exercise_id': 29,
#   'difficulty': -0.053601797087209455,
#   'skill': -0.7684946487129823,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 4.0,
#   'exercise_id': 30,
#   'difficulty': 0.22509968717234413,
#   'skill': 0.5653805344266244,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 2.0,
#   'exercise_id': 31,
#   'difficulty': -0.21490662841544653,
#   'skill': -0.6684946487129824,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 4.0,
#   'exercise_id': 32,
#   'difficulty': 0.6709310009375185,
#   'skill': 0.6653805344266244,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 2.0,
#   'exercise_id': 33,
#   'difficulty': 0.4928586532738607,
#   'skill': -0.5684946487129824,
#   'response': 0},
#  {'student_id': 4,
#   'concept': 0.0,
#   'exercise_id': 34,
#   'difficulty': -0.5170969983699942,
#   'skill': -0.5483564968566016,
#   'response': 0},
#  {'student_id': 4,
#   'concept': 3.0,
#   'exercise_id': 35,
#   'difficulty': -0.6966971402416068,
#   'skill': 1.1374685458401472,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 0.0,
#   'exercise_id': 36,
#   'difficulty': -0.5193471703510235,
#   'skill': -0.6483564968566016,
#   'response': 0},
#  {'student_id': 4,
#   'concept': 3.0,
#   'exercise_id': 37,
#   'difficulty': -0.026160198615202756,
#   'skill': 1.2374685458401473,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 1.0,
#   'exercise_id': 38,
#   'difficulty': -0.28465499701484015,
#   'skill': 1.0303427260207647,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 0.0,
#   'exercise_id': 39,
#   'difficulty': -0.9896105378462159,
#   'skill': -0.7483564968566015,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 0.0,
#   'exercise_id': 40,
#   'difficulty': -0.0019626349165605974,
#   'skill': -0.6483564968566016,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 2.0,
#   'exercise_id': 41,
#   'difficulty': -0.29610299245474186,
#   'skill': -0.6684946487129824,
#   'response': 0},
#  {'student_id': 4,
#   'concept': 2.0,
#   'exercise_id': 42,
#   'difficulty': 0.39625990944493245,
#   'skill': -0.7684946487129823,
#   'response': 0},
#  {'student_id': 4,
#   'concept': 4.0,
#   'exercise_id': 43,
#   'difficulty': -2.1641233284389427,
#   'skill': 0.7653805344266243,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 3.0,
#   'exercise_id': 44,
#   'difficulty': 0.8092447404136248,
#   'skill': 1.3374685458401474,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 4.0,
#   'exercise_id': 45,
#   'difficulty': 0.8853520320789972,
#   'skill': 0.8653805344266243,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 2.0,
#   'exercise_id': 46,
#   'difficulty': -0.9531938619909409,
#   'skill': -0.8684946487129823,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 4.0,
#   'exercise_id': 47,
#   'difficulty': 0.07467215243986028,
#   'skill': 0.9653805344266243,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 0.0,
#   'exercise_id': 48,
#   'difficulty': -0.467589388362164,
#   'skill': -0.5483564968566016,
#   'response': 1},
#  {'student_id': 4,
#   'concept': 3.0,
#   'exercise_id': 49,
#   'difficulty': -0.035869957346887436,
#   'skill': 1.4374685458401475,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 3.0,
#   'exercise_id': 0,
#   'difficulty': 0.8196367556597587,
#   'skill': -0.1350380977991398,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 0.0,
#   'exercise_id': 1,
#   'difficulty': 0.8913040281589579,
#   'skill': 0.2353916417403089,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 0.0,
#   'exercise_id': 2,
#   'difficulty': -0.5531372419066192,
#   'skill': 0.3353916417403089,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 1.0,
#   'exercise_id': 3,
#   'difficulty': 0.26159009433817343,
#   'skill': -0.032335510582020534,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 1.0,
#   'exercise_id': 4,
#   'difficulty': 1.3116985069874925,
#   'skill': 0.06766448941797948,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 1.0,
#   'exercise_id': 5,
#   'difficulty': -1.3698887412990906,
#   'skill': -0.03233551058202053,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 0.0,
#   'exercise_id': 6,
#   'difficulty': -0.679139310129589,
#   'skill': 0.43539164174030887,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 1.0,
#   'exercise_id': 7,
#   'difficulty': -0.8018765891256632,
#   'skill': 0.06766448941797948,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 0.0,
#   'exercise_id': 8,
#   'difficulty': 2.4063205269141164,
#   'skill': 0.5353916417403088,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 4.0,
#   'exercise_id': 9,
#   'difficulty': -1.5078561945166784,
#   'skill': -2.242569157091832,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 3.0,
#   'exercise_id': 10,
#   'difficulty': -0.022425673102465113,
#   'skill': -0.0350380977991398,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 3.0,
#   'exercise_id': 11,
#   'difficulty': -1.0936176901944472,
#   'skill': 0.0649619022008602,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 1.0,
#   'exercise_id': 12,
#   'difficulty': 1.6304738660787466,
#   'skill': 0.16766448941797948,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 4.0,
#   'exercise_id': 13,
#   'difficulty': 0.013057203517021837,
#   'skill': -2.142569157091832,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 2.0,
#   'exercise_id': 14,
#   'difficulty': 0.6043042468961399,
#   'skill': 0.21480069868197393,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 1.0,
#   'exercise_id': 15,
#   'difficulty': 0.5918590749516477,
#   'skill': 0.06766448941797948,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 4.0,
#   'exercise_id': 16,
#   'difficulty': -0.10768281406872234,
#   'skill': -2.242569157091832,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 2.0,
#   'exercise_id': 17,
#   'difficulty': -1.6279829749561132,
#   'skill': 0.11480069868197393,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 0.0,
#   'exercise_id': 18,
#   'difficulty': 0.9484587395186511,
#   'skill': 0.6353916417403088,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 0.0,
#   'exercise_id': 19,
#   'difficulty': -0.6037662024584216,
#   'skill': 0.5353916417403088,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 1.0,
#   'exercise_id': 20,
#   'difficulty': -1.0715204934528981,
#   'skill': 0.16766448941797948,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 4.0,
#   'exercise_id': 21,
#   'difficulty': 1.427237599596769,
#   'skill': -2.342569157091832,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 2.0,
#   'exercise_id': 22,
#   'difficulty': 0.4802272568058525,
#   'skill': 0.21480069868197393,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 2.0,
#   'exercise_id': 23,
#   'difficulty': -2.2122614060271517,
#   'skill': 0.11480069868197393,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 3.0,
#   'exercise_id': 24,
#   'difficulty': -1.0648103301748373,
#   'skill': 0.1649619022008602,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 2.0,
#   'exercise_id': 25,
#   'difficulty': 1.4798167460616558,
#   'skill': 0.21480069868197393,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 1.0,
#   'exercise_id': 26,
#   'difficulty': 1.025125490347724,
#   'skill': 0.2676644894179795,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 0.0,
#   'exercise_id': 27,
#   'difficulty': -0.4466836523187057,
#   'skill': 0.6353916417403088,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 1.0,
#   'exercise_id': 28,
#   'difficulty': -0.30856417843088296,
#   'skill': 0.16766448941797948,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 2.0,
#   'exercise_id': 29,
#   'difficulty': -0.053601797087209455,
#   'skill': 0.11480069868197393,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 4.0,
#   'exercise_id': 30,
#   'difficulty': 0.22509968717234413,
#   'skill': -2.442569157091832,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 2.0,
#   'exercise_id': 31,
#   'difficulty': -0.21490662841544653,
#   'skill': 0.014800698681973923,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 4.0,
#   'exercise_id': 32,
#   'difficulty': 0.6709310009375185,
#   'skill': -2.5425691570918323,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 2.0,
#   'exercise_id': 33,
#   'difficulty': 0.4928586532738607,
#   'skill': 0.11480069868197393,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 0.0,
#   'exercise_id': 34,
#   'difficulty': -0.5170969983699942,
#   'skill': 0.7353916417403088,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 3.0,
#   'exercise_id': 35,
#   'difficulty': -0.6966971402416068,
#   'skill': 0.26496190220086024,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 0.0,
#   'exercise_id': 36,
#   'difficulty': -0.5193471703510235,
#   'skill': 0.8353916417403088,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 3.0,
#   'exercise_id': 37,
#   'difficulty': -0.026160198615202756,
#   'skill': 0.3649619022008602,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 1.0,
#   'exercise_id': 38,
#   'difficulty': -0.28465499701484015,
#   'skill': 0.2676644894179795,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 0.0,
#   'exercise_id': 39,
#   'difficulty': -0.9896105378462159,
#   'skill': 0.9353916417403088,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 0.0,
#   'exercise_id': 40,
#   'difficulty': -0.0019626349165605974,
#   'skill': 0.8353916417403088,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 2.0,
#   'exercise_id': 41,
#   'difficulty': -0.29610299245474186,
#   'skill': 0.21480069868197393,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 2.0,
#   'exercise_id': 42,
#   'difficulty': 0.39625990944493245,
#   'skill': 0.11480069868197393,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 4.0,
#   'exercise_id': 43,
#   'difficulty': -2.1641233284389427,
#   'skill': -2.6425691570918324,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 3.0,
#   'exercise_id': 44,
#   'difficulty': 0.8092447404136248,
#   'skill': 0.4649619022008602,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 4.0,
#   'exercise_id': 45,
#   'difficulty': 0.8853520320789972,
#   'skill': -2.7425691570918325,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 2.0,
#   'exercise_id': 46,
#   'difficulty': -0.9531938619909409,
#   'skill': 0.014800698681973923,
#   'response': 1},
#  {'student_id': 5,
#   'concept': 4.0,
#   'exercise_id': 47,
#   'difficulty': 0.07467215243986028,
#   'skill': -2.8425691570918326,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 0.0,
#   'exercise_id': 48,
#   'difficulty': -0.467589388362164,
#   'skill': 0.9353916417403088,
#   'response': 0},
#  {'student_id': 5,
#   'concept': 3.0,
#   'exercise_id': 49,
#   'difficulty': -0.035869957346887436,
#   'skill': 0.5649619022008602,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 3.0,
#   'exercise_id': 0,
#   'difficulty': 0.8196367556597587,
#   'skill': -0.8630524374600603,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 0.0,
#   'exercise_id': 1,
#   'difficulty': 0.8913040281589579,
#   'skill': -1.501903189558791,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 0.0,
#   'exercise_id': 2,
#   'difficulty': -0.5531372419066192,
#   'skill': -1.6019031895587912,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 1.0,
#   'exercise_id': 3,
#   'difficulty': 0.26159009433817343,
#   'skill': 0.832710533751809,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 1.0,
#   'exercise_id': 4,
#   'difficulty': 1.3116985069874925,
#   'skill': 0.932710533751809,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 1.0,
#   'exercise_id': 5,
#   'difficulty': -1.3698887412990906,
#   'skill': 1.032710533751809,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 0.0,
#   'exercise_id': 6,
#   'difficulty': -0.679139310129589,
#   'skill': -1.501903189558791,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 1.0,
#   'exercise_id': 7,
#   'difficulty': -0.8018765891256632,
#   'skill': 1.132710533751809,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 0.0,
#   'exercise_id': 8,
#   'difficulty': 2.4063205269141164,
#   'skill': -1.401903189558791,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 4.0,
#   'exercise_id': 9,
#   'difficulty': -1.5078561945166784,
#   'skill': -2.254326955197201,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 3.0,
#   'exercise_id': 10,
#   'difficulty': -0.022425673102465113,
#   'skill': -0.7630524374600604,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 3.0,
#   'exercise_id': 11,
#   'difficulty': -1.0936176901944472,
#   'skill': -0.8630524374600603,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 1.0,
#   'exercise_id': 12,
#   'difficulty': 1.6304738660787466,
#   'skill': 1.2327105337518092,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 4.0,
#   'exercise_id': 13,
#   'difficulty': 0.013057203517021837,
#   'skill': -2.154326955197201,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 2.0,
#   'exercise_id': 14,
#   'difficulty': 0.6043042468961399,
#   'skill': 0.030067041014446162,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 1.0,
#   'exercise_id': 15,
#   'difficulty': 0.5918590749516477,
#   'skill': 1.132710533751809,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 4.0,
#   'exercise_id': 16,
#   'difficulty': -0.10768281406872234,
#   'skill': -2.254326955197201,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 2.0,
#   'exercise_id': 17,
#   'difficulty': -1.6279829749561132,
#   'skill': 0.13006704101444616,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 0.0,
#   'exercise_id': 18,
#   'difficulty': 0.9484587395186511,
#   'skill': -1.501903189558791,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 0.0,
#   'exercise_id': 19,
#   'difficulty': -0.6037662024584216,
#   'skill': -1.401903189558791,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 1.0,
#   'exercise_id': 20,
#   'difficulty': -1.0715204934528981,
#   'skill': 1.032710533751809,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 4.0,
#   'exercise_id': 21,
#   'difficulty': 1.427237599596769,
#   'skill': -2.3543269551972013,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 2.0,
#   'exercise_id': 22,
#   'difficulty': 0.4802272568058525,
#   'skill': 0.23006704101444617,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 2.0,
#   'exercise_id': 23,
#   'difficulty': -2.2122614060271517,
#   'skill': 0.33006704101444617,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 3.0,
#   'exercise_id': 24,
#   'difficulty': -1.0648103301748373,
#   'skill': -0.7630524374600604,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 2.0,
#   'exercise_id': 25,
#   'difficulty': 1.4798167460616558,
#   'skill': 0.43006704101444615,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 1.0,
#   'exercise_id': 26,
#   'difficulty': 1.025125490347724,
#   'skill': 0.932710533751809,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 0.0,
#   'exercise_id': 27,
#   'difficulty': -0.4466836523187057,
#   'skill': -1.501903189558791,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 1.0,
#   'exercise_id': 28,
#   'difficulty': -0.30856417843088296,
#   'skill': 0.832710533751809,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 2.0,
#   'exercise_id': 29,
#   'difficulty': -0.053601797087209455,
#   'skill': 0.33006704101444617,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 4.0,
#   'exercise_id': 30,
#   'difficulty': 0.22509968717234413,
#   'skill': -2.4543269551972013,
#   'response': 0},
#  {'student_id': 6,
#   'concept': 2.0,
#   'exercise_id': 31,
#   'difficulty': -0.21490662841544653,
#   'skill': 0.43006704101444615,
#   'response': 1},
#  {'student_id': 6,
#   'concept': 4.0,
#   'exercise_id': 32,
#   'difficulty': 0.6709310009375185,
# ...
#  {'student_id': 17,
#   'concept': 0.0,
#   'exercise_id': 40,
#   'difficulty': -0.0019626349165605974,
#   'skill': 0.8394906355714765,
#   'response': 1},
#  {'student_id': 17,
#   'concept': 2.0,
#   'exercise_id': 41,
#   'difficulty': -0.29610299245474186,
#   'skill': 1.6490495020879716,
#   'response': 1},
#  {'student_id': 17,
#   'concept': 2.0,
#   'exercise_id': 42,
#   'difficulty': 0.39625990944493245,
#   'skill': 1.7490495020879717,
#   'response': 1},
#  {'student_id': 17,
#   'concept': 4.0,
#   'exercise_id': 43,
#   'difficulty': -2.1641233284389427,
#   'skill': -0.556566529990802,
#   'response': 1},
#  {'student_id': 17,
#   'concept': 3.0,
#   'exercise_id': 44,
#   'difficulty': 0.8092447404136248,
#   'skill': 1.2339302710601008,
#   'response': 0},
#  {'student_id': 17,
#   'concept': 4.0,
#   'exercise_id': 45,
#   'difficulty': 0.8853520320789972,
#   'skill': -0.45656652999080205,
#   'response': 0},
#  {'student_id': 17,
#   'concept': 2.0,
#   'exercise_id': 46,
#   'difficulty': -0.9531938619909409,
#   'skill': 1.8490495020879718,
#   'response': 1},
#  {'student_id': 17,
#   'concept': 4.0,
#   'exercise_id': 47,
#   'difficulty': 0.07467215243986028,
#   'skill': -0.556566529990802,
#   'response': 0},
#  {'student_id': 17,
#   'concept': 0.0,
#   'exercise_id': 48,
#   'difficulty': -0.467589388362164,
#   'skill': 0.9394906355714765,
#   'response': 1},
#  {'student_id': 17,
#   'concept': 3.0,
#   'exercise_id': 49,
#   'difficulty': -0.035869957346887436,
#   'skill': 1.1339302710601007,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 3.0,
#   'exercise_id': 0,
#   'difficulty': 0.8196367556597587,
#   'skill': 0.19086884069667368,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 0.0,
#   'exercise_id': 1,
#   'difficulty': 0.8913040281589579,
#   'skill': -0.1385292102186394,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 0.0,
#   'exercise_id': 2,
#   'difficulty': -0.5531372419066192,
#   'skill': -0.03852921021863939,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 1.0,
#   'exercise_id': 3,
#   'difficulty': 0.26159009433817343,
#   'skill': -1.4541679435211365,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 1.0,
#   'exercise_id': 4,
#   'difficulty': 1.3116985069874925,
#   'skill': -1.5541679435211366,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 1.0,
#   'exercise_id': 5,
#   'difficulty': -1.3698887412990906,
#   'skill': -1.4541679435211365,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 0.0,
#   'exercise_id': 6,
#   'difficulty': -0.679139310129589,
#   'skill': 0.06147078978136061,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 1.0,
#   'exercise_id': 7,
#   'difficulty': -0.8018765891256632,
#   'skill': -1.3541679435211365,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 0.0,
#   'exercise_id': 8,
#   'difficulty': 2.4063205269141164,
#   'skill': 0.16147078978136062,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 4.0,
#   'exercise_id': 9,
#   'difficulty': -1.5078561945166784,
#   'skill': 0.6450409796118483,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 3.0,
#   'exercise_id': 10,
#   'difficulty': -0.022425673102465113,
#   'skill': 0.2908688406966737,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 3.0,
#   'exercise_id': 11,
#   'difficulty': -1.0936176901944472,
#   'skill': 0.19086884069667368,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 1.0,
#   'exercise_id': 12,
#   'difficulty': 1.6304738660787466,
#   'skill': -1.4541679435211365,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 4.0,
#   'exercise_id': 13,
#   'difficulty': 0.013057203517021837,
#   'skill': 0.7450409796118482,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 2.0,
#   'exercise_id': 14,
#   'difficulty': 0.6043042468961399,
#   'skill': -0.5832704601244779,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 1.0,
#   'exercise_id': 15,
#   'difficulty': 0.5918590749516477,
#   'skill': -1.5541679435211366,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 4.0,
#   'exercise_id': 16,
#   'difficulty': -0.10768281406872234,
#   'skill': 0.8450409796118482,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 2.0,
#   'exercise_id': 17,
#   'difficulty': -1.6279829749561132,
#   'skill': -0.48327046012447794,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 0.0,
#   'exercise_id': 18,
#   'difficulty': 0.9484587395186511,
#   'skill': 0.06147078978136061,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 0.0,
#   'exercise_id': 19,
#   'difficulty': -0.6037662024584216,
#   'skill': 0.16147078978136062,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 1.0,
#   'exercise_id': 20,
#   'difficulty': -1.0715204934528981,
#   'skill': -1.4541679435211365,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 4.0,
#   'exercise_id': 21,
#   'difficulty': 1.427237599596769,
#   'skill': 0.9450409796118482,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 2.0,
#   'exercise_id': 22,
#   'difficulty': 0.4802272568058525,
#   'skill': -0.38327046012447796,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 2.0,
#   'exercise_id': 23,
#   'difficulty': -2.2122614060271517,
#   'skill': -0.283270460124478,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 3.0,
#   'exercise_id': 24,
#   'difficulty': -1.0648103301748373,
#   'skill': 0.09086884069667367,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 2.0,
#   'exercise_id': 25,
#   'difficulty': 1.4798167460616558,
#   'skill': -0.18327046012447798,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 1.0,
#   'exercise_id': 26,
#   'difficulty': 1.025125490347724,
#   'skill': -1.3541679435211365,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 0.0,
#   'exercise_id': 27,
#   'difficulty': -0.4466836523187057,
#   'skill': 0.2614707897813606,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 1.0,
#   'exercise_id': 28,
#   'difficulty': -0.30856417843088296,
#   'skill': -1.4541679435211365,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 2.0,
#   'exercise_id': 29,
#   'difficulty': -0.053601797087209455,
#   'skill': -0.08327046012447797,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 4.0,
#   'exercise_id': 30,
#   'difficulty': 0.22509968717234413,
#   'skill': 0.8450409796118482,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 2.0,
#   'exercise_id': 31,
#   'difficulty': -0.21490662841544653,
#   'skill': 0.01672953987552203,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 4.0,
#   'exercise_id': 32,
#   'difficulty': 0.6709310009375185,
#   'skill': 0.9450409796118482,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 2.0,
#   'exercise_id': 33,
#   'difficulty': 0.4928586532738607,
#   'skill': 0.11672953987552204,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 0.0,
#   'exercise_id': 34,
#   'difficulty': -0.5170969983699942,
#   'skill': 0.3614707897813606,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 3.0,
#   'exercise_id': 35,
#   'difficulty': -0.6966971402416068,
#   'skill': 0.19086884069667368,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 0.0,
#   'exercise_id': 36,
#   'difficulty': -0.5193471703510235,
#   'skill': 0.4614707897813606,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 3.0,
#   'exercise_id': 37,
#   'difficulty': -0.026160198615202756,
#   'skill': 0.09086884069667367,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 1.0,
#   'exercise_id': 38,
#   'difficulty': -0.28465499701484015,
#   'skill': -1.5541679435211366,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 0.0,
#   'exercise_id': 39,
#   'difficulty': -0.9896105378462159,
#   'skill': 0.5614707897813606,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 0.0,
#   'exercise_id': 40,
#   'difficulty': -0.0019626349165605974,
#   'skill': 0.4614707897813606,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 2.0,
#   'exercise_id': 41,
#   'difficulty': -0.29610299245474186,
#   'skill': 0.21672953987552204,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 2.0,
#   'exercise_id': 42,
#   'difficulty': 0.39625990944493245,
#   'skill': 0.31672953987552205,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 4.0,
#   'exercise_id': 43,
#   'difficulty': -2.1641233284389427,
#   'skill': 1.0450409796118483,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 3.0,
#   'exercise_id': 44,
#   'difficulty': 0.8092447404136248,
#   'skill': -0.009131159303326336,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 4.0,
#   'exercise_id': 45,
#   'difficulty': 0.8853520320789972,
#   'skill': 1.1450409796118484,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 2.0,
#   'exercise_id': 46,
#   'difficulty': -0.9531938619909409,
#   'skill': 0.4167295398755221,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 4.0,
#   'exercise_id': 47,
#   'difficulty': 0.07467215243986028,
#   'skill': 1.0450409796118483,
#   'response': 0},
#  {'student_id': 18,
#   'concept': 0.0,
#   'exercise_id': 48,
#   'difficulty': -0.467589388362164,
#   'skill': 0.3614707897813606,
#   'response': 1},
#  {'student_id': 18,
#   'concept': 3.0,
#   'exercise_id': 49,
#   'difficulty': -0.035869957346887436,
#   'skill': -0.10913115930332634,
#   'response': 0},
#  {'student_id': 19,
#   'concept': 3.0,
#   'exercise_id': 0,
#   'difficulty': 0.8196367556597587,
#   'skill': 1.4055240164455125,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 0.0,
#   'exercise_id': 1,
#   'difficulty': 0.8913040281589579,
#   'skill': 0.8211832051469347,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 0.0,
#   'exercise_id': 2,
#   'difficulty': -0.5531372419066192,
#   'skill': 0.9211832051469346,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 1.0,
#   'exercise_id': 3,
#   'difficulty': 0.26159009433817343,
#   'skill': 0.10104000092472235,
#   'response': 0},
#  {'student_id': 19,
#   'concept': 1.0,
#   'exercise_id': 4,
#   'difficulty': 1.3116985069874925,
#   'skill': 0.0010400009247223396,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 1.0,
#   'exercise_id': 5,
#   'difficulty': -1.3698887412990906,
#   'skill': 0.10104000092472235,
#   'response': 0},
#  {'student_id': 19,
#   'concept': 0.0,
#   'exercise_id': 6,
#   'difficulty': -0.679139310129589,
#   'skill': 1.0211832051469347,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 1.0,
#   'exercise_id': 7,
#   'difficulty': -0.8018765891256632,
#   'skill': 0.0010400009247223396,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 0.0,
#   'exercise_id': 8,
#   'difficulty': 2.4063205269141164,
#   'skill': 1.1211832051469348,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 4.0,
#   'exercise_id': 9,
#   'difficulty': -1.5078561945166784,
#   'skill': -0.15580493416645896,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 3.0,
#   'exercise_id': 10,
#   'difficulty': -0.022425673102465113,
#   'skill': 1.5055240164455126,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 3.0,
#   'exercise_id': 11,
#   'difficulty': -1.0936176901944472,
#   'skill': 1.6055240164455127,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 1.0,
#   'exercise_id': 12,
#   'difficulty': 1.6304738660787466,
#   'skill': 0.10104000092472235,
#   'response': 0},
#  {'student_id': 19,
#   'concept': 4.0,
#   'exercise_id': 13,
#   'difficulty': 0.013057203517021837,
#   'skill': -0.05580493416645896,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 2.0,
#   'exercise_id': 14,
#   'difficulty': 0.6043042468961399,
#   'skill': 0.8090897196318444,
#   'response': 0},
#  {'student_id': 19,
#   'concept': 1.0,
#   'exercise_id': 15,
#   'difficulty': 0.5918590749516477,
#   'skill': 0.0010400009247223396,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 4.0,
#   'exercise_id': 16,
#   'difficulty': -0.10768281406872234,
#   'skill': 0.04419506583354105,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 2.0,
#   'exercise_id': 17,
#   'difficulty': -1.6279829749561132,
#   'skill': 0.7090897196318444,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 0.0,
#   'exercise_id': 18,
#   'difficulty': 0.9484587395186511,
#   'skill': 1.221183205146935,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 0.0,
#   'exercise_id': 19,
#   'difficulty': -0.6037662024584216,
#   'skill': 1.321183205146935,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 1.0,
#   'exercise_id': 20,
#   'difficulty': -1.0715204934528981,
#   'skill': 0.10104000092472235,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 4.0,
#   'exercise_id': 21,
#   'difficulty': 1.427237599596769,
#   'skill': 0.14419506583354105,
#   'response': 0},
#  {'student_id': 19,
#   'concept': 2.0,
#   'exercise_id': 22,
#   'difficulty': 0.4802272568058525,
#   'skill': 0.8090897196318444,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 2.0,
#   'exercise_id': 23,
#   'difficulty': -2.2122614060271517,
#   'skill': 0.9090897196318444,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 3.0,
#   'exercise_id': 24,
#   'difficulty': -1.0648103301748373,
#   'skill': 1.7055240164455128,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 2.0,
#   'exercise_id': 25,
#   'difficulty': 1.4798167460616558,
#   'skill': 1.0090897196318445,
#   'response': 0},
#  {'student_id': 19,
#   'concept': 1.0,
#   'exercise_id': 26,
#   'difficulty': 1.025125490347724,
#   'skill': 0.20104000092472235,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 0.0,
#   'exercise_id': 27,
#   'difficulty': -0.4466836523187057,
#   'skill': 1.421183205146935,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 1.0,
#   'exercise_id': 28,
#   'difficulty': -0.30856417843088296,
#   'skill': 0.3010400009247224,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 2.0,
#   'exercise_id': 29,
#   'difficulty': -0.053601797087209455,
#   'skill': 0.9090897196318445,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 4.0,
#   'exercise_id': 30,
#   'difficulty': 0.22509968717234413,
#   'skill': 0.04419506583354105,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 2.0,
#   'exercise_id': 31,
#   'difficulty': -0.21490662841544653,
#   'skill': 1.0090897196318445,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 4.0,
#   'exercise_id': 32,
#   'difficulty': 0.6709310009375185,
#   'skill': 0.14419506583354105,
#   'response': 0},
#  {'student_id': 19,
#   'concept': 2.0,
#   'exercise_id': 33,
#   'difficulty': 0.4928586532738607,
#   'skill': 1.1090897196318446,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 0.0,
#   'exercise_id': 34,
#   'difficulty': -0.5170969983699942,
#   'skill': 1.5211832051469352,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 3.0,
#   'exercise_id': 35,
#   'difficulty': -0.6966971402416068,
#   'skill': 1.8055240164455129,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 0.0,
#   'exercise_id': 36,
#   'difficulty': -0.5193471703510235,
#   'skill': 1.6211832051469353,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 3.0,
#   'exercise_id': 37,
#   'difficulty': -0.026160198615202756,
#   'skill': 1.905524016445513,
#   'response': 0},
#  {'student_id': 19,
#   'concept': 1.0,
#   'exercise_id': 38,
#   'difficulty': -0.28465499701484015,
#   'skill': 0.40104000092472236,
#   'response': 0},
#  {'student_id': 19,
#   'concept': 0.0,
#   'exercise_id': 39,
#   'difficulty': -0.9896105378462159,
#   'skill': 1.7211832051469353,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 0.0,
#   'exercise_id': 40,
#   'difficulty': -0.0019626349165605974,
#   'skill': 1.8211832051469354,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 2.0,
#   'exercise_id': 41,
#   'difficulty': -0.29610299245474186,
#   'skill': 1.2090897196318446,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 2.0,
#   'exercise_id': 42,
#   'difficulty': 0.39625990944493245,
#   'skill': 1.3090897196318447,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 4.0,
#   'exercise_id': 43,
#   'difficulty': -2.1641233284389427,
#   'skill': 0.04419506583354105,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 3.0,
#   'exercise_id': 44,
#   'difficulty': 0.8092447404136248,
#   'skill': 1.8055240164455129,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 4.0,
#   'exercise_id': 45,
#   'difficulty': 0.8853520320789972,
#   'skill': 0.14419506583354105,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 2.0,
#   'exercise_id': 46,
#   'difficulty': -0.9531938619909409,
#   'skill': 1.4090897196318448,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 4.0,
#   'exercise_id': 47,
#   'difficulty': 0.07467215243986028,
#   'skill': 0.24419506583354106,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 0.0,
#   'exercise_id': 48,
#   'difficulty': -0.467589388362164,
#   'skill': 1.9211832051469355,
#   'response': 1},
#  {'student_id': 19,
#   'concept': 3.0,
#   'exercise_id': 49,
#   'difficulty': -0.035869957346887436,
#   'skill': 1.905524016445513,
#   'response': 1},
#  ...]

# %%
loaded_data_dict = np.load('custom_dataset/data_dict.npy', allow_pickle=True).item()

loaded_student_skills = loaded_data_dict['student_skills']
loaded_exercise_concepts = loaded_data_dict['exercise_concepts']
loaded_exercise_difficulties = loaded_data_dict['exercise_difficulties']
loaded_responses = loaded_data_dict['responses']

print("Data loaded successfully.")
# Out:
# Data loaded successfully.

# %%
loaded_student_skills
# Out:
# array([[ 2.59921859, -0.66654211,  0.21643347, -0.0415731 ,  0.33964991],
#        [ 0.26313948,  1.42022756, -0.41446611, -1.42026068,  1.76742657]])
